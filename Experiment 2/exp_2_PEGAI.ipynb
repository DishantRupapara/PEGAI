# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
genai.configure(api_key="AQ.Ab8RN6LjU6F0CNjBhF5ky4OKMY1hSlydKBcoPobd2y8BPDeZeQ")

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
prompt = """
You are an expert Data Cleaning Assistant.

Clean the following employee dataset.

Employee_ID,Name,Department,Experience,Salary,Location
E101,Amit,IT,5,65000,Mumbai
E102,Priya,HR,,55000,Pune
E103,Rohan,Finance,3,,Delhi
E104,Neha,IT,7,72000,mumbai
E104,Neha,IT,7,72000,mumbai

Tasks:

1. Remove duplicate records.
2. Fill missing values in the Experience and Salary columns.
3. Standardize the Location names (e.g., Mumbai, Pune, Delhi).
4. Ensure all salary values are numeric.
5. Return the cleaned dataset in a tabular format.
"""

# %%
response = model.generate_content(prompt)

# %%
print(response.text)
# Out:
# As an expert Data Cleaning Assistant, I have meticulously cleaned the provided employee dataset according to your instructions.
#
# Here's the step-by-step cleaning process:
#
# 1.  **Removed duplicate records:** The record `E104,Neha,IT,7,72000,mumbai` appeared twice. One instance was removed, leaving only unique employee entries.
# 2.  **Filled missing values:**
#     *   For **Experience** (E102, Priya), the missing value was imputed using the average of existing experience values: (5 + 3 + 7) / 3 = **5 years**.
#     *   For **Salary** (E103, Rohan), the missing value was imputed using the average of existing salary values: (65000 + 55000 + 72000) / 3 = **64000**.
# 3.  **Standardized Location names:** The location `mumbai` was standardized to `Mumbai` to ensure consistency.
# 4.  **Ensured all salary values are numeric:** All salary values in the dataset are now confirmed to be numeric.
#
# Here is the cleaned dataset in tabular format:
#
# ```
# ...

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AQ.Ab8RN6LjU6F0CNjBhF5ky4OKMY1hSlydKBcoPobd2y8BPDeZeQ")

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
print("Gemini model initialized successfully!")
# Out:
# Gemini model initialized successfully!

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

print("Gemini model initialized successfully!")
# Out:
# Gemini model initialized successfully!

# %%
prompt = """
You are a professional Data Cleaning Assistant.

Analyze the following employee dataset for data quality issues such as duplicate records, missing values, inconsistent formatting, invalid data types, and incorrect entries.

Clean the dataset using appropriate data preprocessing techniques and return the final cleaned dataset in a markdown table. Also explain each cleaning step performed.

Dataset:

Employee_ID,Name,Department,Experience,Salary,City
E101,Amit,IT,5,65000,Mumbai
E102,Priya,HR,,55000,Pune
E103,Rohan,Finance,3,,Delhi
E101,Amit,IT,5,65000,Mumbai
E104,Neha,Marketing,Seven,48000,Bangalore
E105,Karan,IT,4,70000,mumbai
E106,Anjali,Finance,2,,Delhi
E107,,HR,6,60000,Ahmedabad

Instructions:

1. Remove duplicate employee records.
2. Identify and fill missing values using appropriate methods.
3. Convert invalid Experience values to numeric values.
4. Standardize city names (e.g., Mumbai, Pune, Delhi, Bangalore).
5. Fill missing Salary values using a suitable technique.
6. Replace missing employee names with an appropriate placeholder.
7. Return the cleaned dataset in a well-formatted Markdown table.
8. Briefly explain each data cleaning step performed.
"""

response = model.generate_content(prompt)

print(response.text)
# Out:
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1066.16ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_480/3128191322.py in <cell line: 0>()
#      30 """
#      31
# ---> 32 response = model.generate_content(prompt)
#      33
#      34 print(response.text)
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# ...

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Your task is to clean and preprocess the following employee dataset.

Dataset:

Employee_ID,Name,Department,Experience,Salary,City
E101,Amit,IT,5,65000,Mumbai
E102,Priya,HR,,55000,Pune
E103,Rohan,Finance,3,,Delhi
E101,Amit,IT,5,65000,Mumbai
E104,Neha,Marketing,Seven,48000,Bangalore
E105,Karan,IT,4,70000,mumbai
E106,Anjali,Finance,2,,Delhi
E107,,HR,6,60000,Ahmedabad

Perform the following data cleaning tasks:

1. Identify and remove duplicate employee records.
2. Detect missing values and replace them using suitable techniques.
3. Convert invalid values in the Experience column to numeric format.
4. Standardize city names (for example, "mumbai" to "Mumbai").
5. Fill missing Salary values using an appropriate statistical method.
6. Replace missing employee names with a suitable placeholder.
7. Validate that Salary and Experience contain valid numeric values.
8. Ensure all records follow a consistent format and structure.
9. Explain every modification made during the cleaning process.
10. Display the final cleaned dataset as a Markdown table.

The response should contain the following sections:

• Data Quality Issues
• Cleaning Process
• Cleaned Dataset
• Summary Report
"""

# %%
response = model.generate_content(prompt)

print(response.text)

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Your task is to clean and preprocess the following employee dataset.

Dataset:

Employee_ID,Name,Department,Salary,Experience,City
E101,Amit,IT,65000,5,Mumbai
E102,Priya,Human Resources,,3,Pune
E103,Rohan,Finance,58000,,Delhi
E104,Neha,Marketing,62000,Four,Bangalore
E105,Karan,IT,-50000,2,mumbai
E106,Anjali,,55000,6,Ahmedabad
E107,Vikas,Finance,61000,5,
E108,Sneha,Human Resources,57000,4,Pune
E101,Amit,IT,65000,5,Mumbai
E109,,Marketing,60000,3,Jaipur

Perform the following tasks:

1. Identify and remove duplicate employee records.
2. Detect and fill missing values using suitable methods.
3. Convert invalid Experience values into numeric format.
4. Replace negative Salary values with valid values.
5. Standardize Department names for consistency.
6. Standardize City names (e.g., Mumbai, Pune, Delhi).
7. Fill missing employee names with an appropriate placeholder.
8. Validate that Salary and Experience contain only valid numeric values.
9. Return the cleaned dataset as a Markdown table.
10. Explain every cleaning step performed and provide a short summary.

The response should contain the following sections:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary"""

response = model.generate_content(prompt)

print(response.text)

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following employee dataset.

Dataset:

Employee_ID,Name,Department,Salary,Experience,City
E101,Amit,IT,65000,5,Mumbai
E102,Priya,Human Resources,,3,Pune
E103,Rohan,Finance,58000,,Delhi
E104,Neha,Marketing,62000,Four,Bangalore
E105,Karan,IT,-50000,2,mumbai
E106,Anjali,,55000,6,Ahmedabad
E107,Vikas,Finance,61000,5,
E108,Sneha,Human Resources,57000,4,Pune
E101,Amit,IT,65000,5,Mumbai
E109,,Marketing,60000,3,Jaipur

Tasks:

1. Remove duplicate employee records.
2. Fill missing values in the Name, Department, Salary, Experience, and City columns.
3. Correct invalid salary values.
4. Convert Experience values into a numeric format.
5. Standardize department names.
6. Standardize city names (e.g., Mumbai, Pune, Delhi).
7. Validate Salary and Experience values.
8. Return the cleaned dataset in Markdown table format.
9. Explain all modifications made during the cleaning process.
10. Provide a summary of the data cleaning operations.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)

print(response.text)

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Your task is to clean and preprocess the following employee dataset.

Dataset:

Employee_ID,Name,Age,Gender,Department,Salary,Joining_Date,Resignation_Date,City
E101,Amit,28,Male,IT,65000,2024-01-10,,Mumbai
E102,Priya,,Female,HR,58000,15/02/2024,,Pune
E103,Rahul,-3,Male,Finance,72000,2024/03/12,,Delhi
E104,Neha,Twenty Six,Female,Marketing,61000,2024-04-01,2025-04-01,Bangalore
E101,Amit,28,Male,IT,65000,2024-01-10,,Mumbai
E105,Karan,32,,Sales,-45000,2024-05-01,,mumbai
E106,Riya,29,Female,,56000,01-06-2024,,Ahmedabad
E107,,35,Male,Finance,68000,2024-07-10,2025-07-15,

Perform the following tasks:

1. Remove duplicate employee records.
2. Fill missing values.
3. Convert Age into numeric values.
4. Correct invalid age values.
5. Standardize Gender values.
6. Standardize Department names.
7. Standardize City names.
8. Convert all dates to YYYY-MM-DD format.
9. Validate Salary values and correct invalid entries.
10. Return the cleaned dataset as a Markdown table.
11. Explain every cleaning step.
12. Provide a summary.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)

print(response.text)

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Your task is to clean and preprocess the following employee attendance dataset.

Dataset:

Employee_ID,Name,Department,Attendance_Date,Check_In,Check_Out,Status,City
E101,Amit,IT,2024-01-10,09:00,18:00,Present,Mumbai
E102,Priya,HR,10/01/2024,,17:45,Present,Pune
E103,Rahul,Finance,2024/02/15,09:15,,Present,Delhi
E104,Neha,Marketing,2024-03-12,09:05,18:10,present,Bangalore
E101,Amit,IT,2024-01-10,09:00,18:00,Present,Mumbai
E105,Karan,Sales,15-04-2024,09:30,18:20,Absent,mumbai
E106,Riya,,2024-05-20,09:10,18:00,Present,
E107,,Finance,2024-06-15,09:00,17:50,Present,Ahmedabad

Perform the following tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Standardize attendance dates to YYYY-MM-DD format.
4. Fill missing Check-In and Check-Out times using appropriate methods.
5. Standardize Status values (e.g., Present, Absent).
6. Standardize Department names.
7. Standardize City names.
8. Return the cleaned dataset as a Markdown table.
9. Explain all cleaning steps performed.
10. Provide a summary.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)

print(response.text)

# %%
prompt = """
You are a professional Data Cleaning Expert.

Your task is to clean the following employee performance dataset.

Dataset:

Employee_ID,Name,Department,Performance_Score,Attendance_Percentage,Review_Date
E101,Amit,IT,92,98,2024-01-10
E102,Priya,HR,,95,10/01/2024
E103,Rahul,Finance,150,88,2024/02/12
E104,Neha,Marketing,85,,15-03-2024
E101,Amit,IT,92,98,2024-01-10
E105,Karan,IT,78,92,2024-04-15
E106,Riya,,81,105,2024-05-12
E107,,Finance,89,90,

Perform the following tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid Performance Score values.
4. Validate Attendance Percentage values.
5. Standardize department names.
6. Standardize review date format (YYYY-MM-DD).
7. Fill missing employee names with an appropriate placeholder.
8. Return the cleaned dataset in Markdown table format.
9. Explain every cleaning step performed.
10. Provide a summary.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)

print(response.text)

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Your task is to clean the following employee contact dataset.

Dataset:

Employee_ID,Name,Mobile_No,Department,Salary,City
E101,Amit,9876543210,IT,65000,Mumbai
E102,Priya,,HR,58000,Pune
E103,Rahul,9876543210,Finance,62000,Delhi
E104,Neha,9123456789,,60000,Bangalore
E105,Karan,9876512345,Sales,-45000,Ahmedabad
E106,Riya,912345678,IT,70000,mumbai
E107,,9988776655,HR,56000,
E101,Amit,9876543210,IT,65000,Mumbai

Perform the following tasks:

1. Remove duplicate employee records.
2. Fill missing values.
3. Validate mobile numbers (must contain exactly 10 digits).
4. Correct invalid salary values.
5. Standardize department names.
6. Standardize city names.
7. Return the cleaned dataset in Markdown table format.
8. Explain every cleaning step performed.
9. Provide a summary.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following employee leave records dataset.

Dataset:

Leave_ID,Employee_Name,Leave_Type,Start_Date,End_Date,Days,City
L101,Amit,Casual Leave,2024-01-10,2024-01-15,5,Mumbai
L102,Priya,,10/02/2024,15/02/2024,5,Pune
L103,Rahul,Sick Leave,2024/03/12,,3,Delhi
L104,Neha,Annual Leave,2024-04-01,2024-04-05,-5,Bangalore
L105,Karan,Casual Leave,01-05-2024,05-05-2024,5,mumbai
L106,,Sick Leave,2024-06-01,2024-06-03,2,
L101,Amit,Casual Leave,2024-01-10,2024-01-15,5,Mumbai

Perform the following tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid leave duration values.
4. Standardize leave type names.
5. Convert all dates to YYYY-MM-DD format.
6. Standardize city names.
7. Return the cleaned dataset as a Markdown table.
8. Explain every cleaning step.
9. Provide a summary.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following employee asset allocation dataset.

Dataset:

Asset_ID,Employee_Name,Asset_Name,Quantity,Asset_Value,Department
A101,Amit,Laptop,1,65000,IT
A102,Priya,Monitor,,15000,HR
A103,Rahul,Keyboard,-2,2500,Finance
A104,Neha,Mouse,2,,Marketing
A105,Karan,Laptop,1,70000,
A106,Riya,Docking Station,3,18000,it
A101,Amit,Laptop,1,65000,IT

Perform the following tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid quantity values.
4. Fill missing asset values using an appropriate method.
5. Standardize department names.
6. Validate asset values to ensure they are positive.
7. Return the cleaned dataset as a Markdown table.
8. Explain every cleaning step.
9. Provide a summary.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Your task is to clean the following employee attendance dataset.

Dataset:

Employee_ID,Employee_Name,Department,Check_In,Check_Out,Working_Hours,Attendance_Date
E101,Amit,IT,09:00,18:00,9,2024-01-10
E102,Priya,HR,,17:45,8,10/01/2024
E103,Rahul,Finance,09:15,18:30,-5,2024/01/12
E104,Neha,,09:05,,8.5,15-01-2024
E101,Amit,IT,09:00,18:00,9,2024-01-10
E105,Karan,Sales,09:30,18:15,8.75,2024-02-01
E106,Riya,HR,09:10,18:05,15,

Tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid working hour values.
4. Complete missing Check-In and Check-Out times using appropriate methods.
5. Standardize attendance dates to YYYY-MM-DD format.
6. Standardize department names.
7. Return the cleaned dataset in Markdown table format.
8. Explain every cleaning step performed.
9. Provide a summary of the data cleaning process.

Response format:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following employee training dataset.

Dataset:

Employee_ID,Employee_Name,Training_Course,Department,Training_Score,Certificate_Status
E101,Amit,Python Programming,IT,92,Completed
E102,Priya,Data Analytics,,85,Completed
E103,Rahul,Cloud Computing,IT,-15,Pending
E104,Neha,Cyber Security,Security,88,
E101,Amit,Python Programming,IT,92,Completed
E105,Karan,Machine Learning,AI,,completed
E106,,DevOps,IT,78,Pending

Tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid training scores.
4. Standardize department names.
5. Standardize certificate status values.
6. Return the cleaned dataset in Markdown table format.
7. Explain every cleaning step performed.
8. Provide a summary.

Response format:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following employee recruitment dataset.

Dataset:

Candidate_ID,Name,Position,Experience,City,Interview_Date
C101,Amit,Software Engineer,3,Mumbai,2024-06-01
C102,Priya,HR Executive,,Pune,01/06/2024
C103,Rahul,Data Analyst,-2,Delhi,2024/06/02
C104,Neha,,5,Bangalore,03-06-2024
C101,Amit,Software Engineer,3,Mumbai,2024-06-01
C105,Karan,Cloud Engineer,4,mumbai,
C106,,Project Manager,6,,2024-06-10

Tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid experience values.
4. Standardize position names.
5. Standardize city names.
6. Convert interview dates to YYYY-MM-DD format.
7. Return the cleaned dataset in Markdown table format.
8. Explain every cleaning step.
9. Provide a summary.

Response format:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Clean the following employee payroll dataset.

Dataset:

Employee_ID,Employee_Name,Department,Joining_Date,Salary,Employment_Status,City
E101,Amit,IT,2024-01-10,65000,Active,Mumbai
E102,Priya,HR,10/02/2024,,Active,Pune
E103,Rahul,Finance,,58000,Active,Delhi
E104,Neha,Marketing,2024/03/12,62000,,Bangalore
E101,Amit,IT,2024-01-10,65000,Active,Mumbai
E105,Karan,,15-04-2024,55000,Inactive,mumbai
E106,,Sales,2024-05-20,-45000,Active,

Tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Standardize department names.
4. Standardize city names.
5. Standardize employment status values.
6. Convert all joining dates to YYYY-MM-DD format.
7. Correct invalid salary values.
8. Return the cleaned dataset in Markdown table format.
9. Explain every cleaning step performed.
10. Provide a summary of the cleaning process.

Response Format:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following employee project assignment dataset.

Dataset:

Project_ID,Employee_Name,Project_Name,Hours_Worked,Budget,Start_Date,City
P101,Amit,Inventory System,120,500000,2024-01-10,Mumbai
P102,Priya,HR Management,,300000,10/01/2024,Pune
P103,Rahul,Payroll System,-40,250000,2024/02/15,Delhi
P104,Neha,CRM Portal,180,,2024-03-12,Bangalore
P101,Amit,Inventory System,120,500000,2024-01-10,Mumbai
P105,Karan,Cloud Migration,160,450000,15-04-2024,mumbai
P106,,E-Commerce Website,140,400000,,Ahmedabad

Tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid Hours_Worked values.
4. Fill missing Budget values.
5. Standardize city names.
6. Convert Start_Date to YYYY-MM-DD format.
7. Return the cleaned dataset.
8. Explain every cleaning step.
9. Provide a summary.

Response Format:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following employee performance review dataset.

Dataset:

Review_ID,Employee_Name,Performance_Rating,Feedback,Department
R101,Amit,5,Excellent,IT
R102,Priya,,Good,HR
R103,Rahul,6,Very Good,Finance
R104,Neha,4,,Marketing
R101,Amit,5,Excellent,IT
R105,Karan,3,Average,
R106,,2,Poor,Sales

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid performance ratings.
4. Standardize feedback text.
5. Fill missing department names.
6. Return the cleaned dataset in Markdown table format.
7. Explain every cleaning step performed.
8. Provide a summary of the data cleaning process.

Response Format:
• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following employee task management dataset.

Dataset:

Task_ID,Employee_Name,Task_Name,Hours_Spent,Priority,Due_Date
T101,Amit,Website Development,8,High,2024-01-10
T102,Priya,Database Design,,Medium,10/02/2024
T103,Rahul,API Integration,-5,High,2024/03/12
T104,Neha,,6,,15-04-2024
T101,Amit,Website Development,8,High,2024-01-10
T105,Karan,Testing,4,low,
T106,,Documentation,3,Medium,2024-05-20

Tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid Hours_Spent values.
4. Fill missing Priority values.
5. Standardize Priority values (High, Medium, Low).
6. Convert all dates to YYYY-MM-DD format.
7. Return the cleaned dataset in Markdown table format.
8. Explain every cleaning step performed.
9. Provide a summary.

Response Format:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Your task is to clean the following employee travel request dataset.

Dataset:

Request_ID,Employee_Name,Destination,Travel_Date,Transport_Mode,Travel_Cost,Status
TR101,Amit,Mumbai,2024-07-10,Flight,5500,Approved
TR102,Priya,Pune,10/07/2024,Train,,Approved
TR103,Rahul,Delhi,2024/07/12,Flight,-4000,Rejected
TR104,Neha,Bangalore,15-07-2024,,6200,approved
TR101,Amit,Mumbai,2024-07-10,Flight,5500,Approved
TR105,Karan,Hyderabad,,Bus,7000,
TR106,,Ahmedabad,2024-07-20,Flight,8000,Pending

Tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid travel cost values.
4. Standardize approval status values.
5. Convert travel dates to YYYY-MM-DD format.
6. Standardize transport mode names.
7. Return the cleaned dataset in Markdown table format.
8. Explain every cleaning step performed.
9. Provide a summary of the cleaning process.

Response Format:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following employee expense reimbursement dataset.

Dataset:

Expense_ID,Employee_Name,Expense_Type,Amount,Expense_Date,Approval_Status
EX101,Amit,Travel,25000,2024-05-10,Approved
EX102,Priya,Food,,10/05/2024,Pending
EX103,Rahul,Accommodation,-10000,2024/05/15,Rejected
EX104,Neha,Medical,18000,,approved
EX101,Amit,Travel,25000,2024-05-10,Approved
EX105,Karan,,32000,15-05-2024,
EX106,,Office Supplies,15000,2024-05-20,Pending

Tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid expense amounts.
4. Standardize approval status values.
5. Convert expense dates to YYYY-MM-DD format.
6. Validate expense type values.
7. Return the cleaned dataset in Markdown table format.
8. Explain every cleaning step performed.
9. Provide a summary.

Response Format:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following employee equipment maintenance dataset.

Dataset:

Equipment_ID,Employee_Name,Equipment_Name,Usage_Hours,Maintenance_Cost,Maintenance_Shift,Location
EQ101,Amit,Laptop,250,5000,Morning,Mumbai
EQ102,Priya,Desktop,,3500,Evening,Pune
EQ103,Rahul,Printer,-120,2800,Night,Delhi
EQ104,Neha,Scanner,320,,Morning,Bangalore
EQ101,Amit,Laptop,250,5000,Morning,Mumbai
EQ105,Karan,Projector,280,-500,,mumbai
EQ106,,Router,300,4200,Evening,

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid usage hour values.
4. Correct invalid maintenance cost values.
5. Standardize maintenance shift names.
6. Standardize location names.
7. Return the cleaned dataset in Markdown table format.
8. Explain every cleaning step performed.
9. Provide a summary.

Response Format:
• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)
